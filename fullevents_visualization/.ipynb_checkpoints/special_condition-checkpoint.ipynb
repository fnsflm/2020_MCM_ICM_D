# %%
import pandas as pd
from pyecharts.charts import Line
import numpy as np

# %%
data = pd.read_csv('fullevents.csv')
data
# Out:
#        MatchID      TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 0            1     Huskies     Huskies_G1                 NaN          1H
# 1            1   Opponent1   Opponent1_D1                 NaN          1H
# 2            1     Huskies     Huskies_F1                 NaN          1H
# 3            1   Opponent1   Opponent1_D2                 NaN          1H
# 4            1     Huskies     Huskies_D1          Huskies_F1          1H
# ...        ...         ...            ...                 ...         ...
# 59266       38     Huskies     Huskies_D4                 NaN          2H
# 59267       38  Opponent14  Opponent14_M5                 NaN          2H
# 59268       38     Huskies     Huskies_D1                 NaN          2H
# 59269       38  Opponent14  Opponent14_D7                 NaN          2H
# 59270       38  Opponent14  Opponent14_D7                 NaN          2H
#
#          EventTime           EventType EventSubType  EventOrigin_x  \
# ...

# %%
data1 = data[data['MatchID']==1]
data1
# Out:
#       MatchID     TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 0           1    Huskies     Huskies_G1                 NaN          1H
# 1           1  Opponent1   Opponent1_D1                 NaN          1H
# 2           1    Huskies     Huskies_F1                 NaN          1H
# 3           1  Opponent1   Opponent1_D2                 NaN          1H
# 4           1    Huskies     Huskies_D1          Huskies_F1          1H
# ...       ...        ...            ...                 ...         ...
# 1516        1  Opponent1   Opponent1_M1                 NaN          2H
# 1517        1    Huskies     Huskies_M1                 NaN          2H
# 1518        1  Opponent1   Opponent1_M1                 NaN          2H
# 1519        1    Huskies     Huskies_G1                 NaN          2H
# 1520        1  Opponent1   Opponent1_D2                 NaN          2H
#
#         EventTime  EventType            EventSubType  EventOrigin_x  \
# ...

# %%
# 为空的情况
data1.isnull().any(axis=0)
# Out:
# MatchID                False
# TeamID                 False
# OriginPlayerID         False
# DestinationPlayerID     True
# MatchPeriod            False
# EventTime              False
# EventType              False
# EventSubType            True
# EventOrigin_x           True
# EventOrigin_y           True
# EventDestination_x      True
# EventDestination_y      True
# dtype: bool

# %%
# subtype为空
data1.loc[data1['EventSubType'].isnull()]
# Out:
#       MatchID     TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 128         1  Opponent1   Opponent1_D1                 NaN          1H
# 247         1    Huskies     Huskies_F3                 NaN          1H
# 356         1    Huskies     Huskies_F1                 NaN          1H
# 692         1  Opponent1   Opponent1_D4                 NaN          1H
# 734         1  Opponent1   Opponent1_D1                 NaN          1H
# 1234        1  Opponent1   Opponent1_F4                 NaN          2H
# 1273        1  Opponent1   Opponent1_F4                 NaN          2H
# 1352        1  Opponent1   Opponent1_F4                 NaN          2H
#
#         EventTime EventType EventSubType  EventOrigin_x  EventOrigin_y  \
# 128    457.039100   Offside          NaN           84.0           12.0
# 247    892.350866   Offside          NaN           76.0            8.0
# 356   1250.066342   Offside          NaN           74.0           98.0
# ...

# %%
# 坐标为空
data1.loc[data1['EventOrigin_x'].isnull()]
# Out:
#       MatchID     TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 750         1    Huskies     Huskies_D2          Huskies_D5          2H
# 989         1    Huskies     Huskies_M2          Huskies_M4          2H
# 1166        1  Opponent1   Opponent1_F2        Opponent1_F5          2H
# 1167        1  Opponent1   Opponent1_F1        Opponent1_F4          2H
# 1254        1    Huskies     Huskies_F3          Huskies_M5          2H
#
#       EventTime     EventType  EventSubType  EventOrigin_x  EventOrigin_y  \
# 750        60.0  Substitution  Substitution            NaN            NaN
# 989       900.0  Substitution  Substitution            NaN            NaN
# 1166     1620.0  Substitution  Substitution            NaN            NaN
# 1167     1620.0  Substitution  Substitution            NaN            NaN
# 1254     1920.0  Substitution  Substitution            NaN            NaN
#
#       EventDestination_x  EventDestination_y
# ...
